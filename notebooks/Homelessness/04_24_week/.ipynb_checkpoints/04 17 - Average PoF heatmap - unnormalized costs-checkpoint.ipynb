# %%
import pandas as pd
import numpy as np
np.random.seed(0)
from scipy.stats import beta as sp_beta

import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
plt.rcParams['figure.figsize'] = 20, 13
plt.rcParams['font.size'] = 20
plt.rcParams['lines.linewidth'] = 2
import seaborn as sns

import sys
sys.path.insert(0, '../../..')
import assignment
import leximin_assignment
import matrix_gen

from tqdm import tqdm

import warnings

# %%
N = 30
N_INTVS = 5
N_EXPERIMENTS = 500
CAPACITIES = np.ones((N_INTVS,), dtype=int) * (N // N_INTVS)

ALPHAS = [0.01 * i for i in range(1, 101, 2)]
BETAS = [0.01 * i for i in range(1, 101, 2)]

# %%
pof_pop = [[[] for __ in BETAS] for _ in ALPHAS]

for a_id, a in enumerate(ALPHAS):
    for b_id, b in enumerate(BETAS):
        print(a, b)
        
        matrix_generator = matrix_gen.MatrixGenerator(
            np.random.beta, (a, b), N, N_INTVS
        )
        
        success_count = 0
        while success_count < N_EXPERIMENTS:
            # print(a, b, success_count)
            
            (_, sorted_matrix), __ = matrix_generator.get_increase_matrix_pair(
                round_=False
            )

            _, counts = np.unique(sorted_matrix, return_counts=True)
            if np.any(counts > 1):
                continue


            # Efficient
            eff_assigner = assignment.AssignmentHelperV2(
                sorted_matrix, CAPACITIES
            )
            eff_assignments = eff_assigner.ip_solve()
            eff_cost = eff_assigner.get_cost(
                eff_assignments, cost_matrix=sorted_matrix
            )

            # Leximin
            lex_assigner = leximin_assignment.RowSortedLeximinAssignmentHelper(
                sorted_matrix, CAPACITIES
            )
            lex_assignments = lex_assigner.solve()
            lex_cost = eff_assigner.get_cost(
                lex_assignments, cost_matrix=sorted_matrix
            )


            pof_pop[a_id][b_id].append(lex_cost / eff_cost)
            success_count += 1
# Out:
# 0.1 0.1
# 0.1 0.3
# 0.1 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2e0961fbe558> in <module>
#      26                 sorted_matrix, CAPACITIES
#      27             )
# ---> 28             eff_assignments = eff_assigner.ip_solve()
#      29             eff_cost = eff_assigner.get_cost(
#      30                 eff_assignments, cost_matrix=sorted_matrix
#
# ~/PycharmProjects/BayesFAI/assignment.py in ip_solve(self)
#     189             ) <= self.capacities[intv_id]
#     190
# --> 191         self.prob.solve(solver=pulp.solvers.GUROBI_CMD())
#     192         if pulp.LpStatus[self.prob.status] != 'Optimal':
#     193             return False
#
# ~/anaconda3/envs/BayesFAI/lib/python3.7/site-packages/pulp/pulp.py in solve(self, solver, **kwargs)
#    1711         #time it
#    1712         self.solutionTime = -clock()
# -> 1713         status = solver.actualSolve(self, **kwargs)
#    1714         self.solutionTime += clock()
#    1715         self.restoreObjective(wasNone, dummyVar)
#
# ~/anaconda3/envs/BayesFAI/lib/python3.7/site-packages/pulp/solvers.py in actualSolve(self, lp)
#    2026             tmpSol = lp.name+"-pulp.sol"
#    2027             tmpMst = lp.name + "-pulp.mst"
# -> 2028         vs = lp.writeLP(tmpLp, writeSOS = 1)
#    2029         try: os.remove(tmpSol)
#    2030         except: pass
#
# ~/anaconda3/envs/BayesFAI/lib/python3.7/site-packages/pulp/pulp.py in writeLP(self, filename, writeSOS, mip, max_length)
#    1569             f.write(constraint.asCplexLpConstraint(k))
#    1570         # check if any names are longer than 100 characters
# -> 1571         self.checkLengthVars(max_length)
#    1572         vs = self.variables()
#    1573         # check for repeated names
#
# ~/anaconda3/envs/BayesFAI/lib/python3.7/site-packages/pulp/pulp.py in checkLengthVars(self, max_length)
#    1627
#    1628     def checkLengthVars(self, max_length):
# -> 1629         vs = self.variables()
#    1630         long_names = [v.name for v in vs if len(v.name) > max_length]
#    1631         if long_names:
#
# ~/anaconda3/envs/BayesFAI/lib/python3.7/site-packages/pulp/pulp.py in variables(self)
#    1301         variables = self._variables
#    1302         #sort the varibles DSU
# -> 1303         variables = [[v.name, v] for v in variables]
#    1304         variables.sort()
#    1305         variables = [v for _, v in variables]
#
# ~/anaconda3/envs/BayesFAI/lib/python3.7/site-packages/pulp/pulp.py in <listcomp>(.0)
#    1301         variables = self._variables
#    1302         #sort the varibles DSU
# -> 1303         variables = [[v.name, v] for v in variables]
#    1304         variables.sort()
#    1305         variables = [v for _, v in variables]
#
# ~/anaconda3/envs/BayesFAI/lib/python3.7/site-packages/pulp/pulp.py in getName(self)
#     173             self.__name = None
#     174     def getName(self):
# --> 175         return self.__name
#     176     name = property(fget = getName,fset = setName)
#     177
#
# KeyboardInterrupt:

# %%
sns.heatmap(
    np.mean(pof_pop, axis=2),
    annot=True, fmt='.4f',
    xticklabels=BETAS, yticklabels=ALPHAS
)
plt.ylabel('alpha')
plt.xlabel('beta')

plt.show()

# %%
sns.heatmap(
    np.max(pof_pop, axis=2),
    annot=True, fmt='.4f',
    xticklabels=BETAS, yticklabels=ALPHAS
)
plt.ylabel('alpha')
plt.xlabel('beta')

plt.show()

# %% [markdown]
# # C(L_u) / C(L_n)

# %%
cost_ratio_pop = [[[] for __ in BETAS] for _ in ALPHAS]

for a_id, a in enumerate(ALPHAS):
    print(a)
    for b_id, b in enumerate(BETAS):
        # print(a, b)
        
        matrix_generator = matrix_gen.MatrixGenerator(
            np.random.beta, (a, b), N, N_INTVS
        )
        
        success_count = 0
        while success_count < N_EXPERIMENTS:
            # print(a, b, success_count)
            
            (_, sorted_matrix), (__, sorted_increase_matrix) = matrix_generator.get_increase_matrix_pair(
                round_=False
            )

            # _, counts = np.unique(sorted_matrix, return_counts=True)
            # if np.any(counts > 1):
            #     continue


            # Norm leximin
            lex_n_assigner = leximin_assignment.RowSortedLeximinAssignmentHelper(
                sorted_increase_matrix, CAPACITIES
            )
            lex_n_assignments = lex_n_assigner.solve()
            lex_n_cost = lex_n_assigner.get_cost(
                lex_n_assignments, cost_matrix=sorted_matrix
            )
            
            # Un-norm Leximin
            lex_u_assigner = leximin_assignment.RowSortedLeximinAssignmentHelper(
                sorted_matrix, CAPACITIES
            )
            lex_u_assignments = lex_u_assigner.solve()
            lex_u_cost = lex_u_assigner.get_cost(
                lex_u_assignments, cost_matrix=sorted_matrix
            )


            cost_ratio_pop[a_id][b_id].append(lex_u_cost / lex_n_cost)
            success_count += 1
# Out:
# 0.01
# 0.03
# 0.05
# 0.07
# 0.09
# 0.11
# 0.13
# 0.15
# 0.17
# 0.19
# 0.21
# 0.23
# 0.25
# 0.27
# 0.29
# 0.31
# 0.33
# 0.35000000000000003
# 0.37
# 0.39
# 0.41000000000000003
# 0.43
# 0.45
# 0.47000000000000003
# 0.49
# 0.51
# 0.53
# 0.55
# 0.5700000000000001
# 0.59
# 0.61
# 0.63
# 0.65
# 0.67
# 0.6900000000000001
# 0.71
# 0.73
# 0.75
# 0.77
# 0.79
# 0.81
# 0.8300000000000001
# 0.85
# 0.87
# 0.89
# 0.91
# 0.93
# 0.9500000000000001
# 0.97
# 0.99

# %%
sns.heatmap(
    np.mean(cost_ratio_pop, axis=2),
    annot=True, fmt='.4f',
    xticklabels=BETAS, yticklabels=ALPHAS
)
plt.ylabel('alpha')
plt.xlabel('beta')

plt.show()

# %% [markdown]
# # 15x15 matrices

# %%
sns.heatmap(
    np.mean(cost_ratio_pop, axis=2),
    annot=True, fmt='.4f',
    xticklabels=BETAS, yticklabels=ALPHAS
)
plt.ylabel('alpha')
plt.xlabel('beta')

plt.show()

# %%
sns.heatmap(
    np.mean(cost_ratio_pop, axis=2),
    annot=True, fmt='.4f',
    xticklabels=BETAS, yticklabels=ALPHAS
)
plt.ylabel('alpha')
plt.xlabel('beta')

plt.show()

# %% [markdown]
# # 30x5 matrices

# %%
sns.heatmap(
    np.mean(cost_ratio_pop, axis=2),
    annot=True, fmt='.4f',
    xticklabels=BETAS, yticklabels=ALPHAS
)
plt.ylabel('alpha')
plt.xlabel('beta')

plt.show()

# %%
plt.figure(figsize=(25, 20))

sns.heatmap(
    np.mean(cost_ratio_pop, axis=2),
    # annot=True, fmt='.4f',
    xticklabels=np.round(BETAS, 2), yticklabels=np.round(ALPHAS, 2)
)
plt.ylabel('alpha')
plt.xlabel('beta')

plt.show()
